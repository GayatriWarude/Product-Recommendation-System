# %% [markdown]
# # Product Reccomendation System

# %% [markdown]
# ### EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## load dataset
df=pd.read_csv('rating_short.csv')
df.head()
# Out:
#            userid   productid  rating        date
# 0  A1Z3YJF1S8Z1M3  B000M9ISQ2     5.0  1199750400
# 1   ALDXDYEGKB27G  B002L6HE9G     4.0  1331337600
# 2  A15LOGO6NBSI6B  B007MXGG5Q     5.0  1358640000
# 3  A23LX12CA3G4FG  B008HOEDYU     1.0  1385337600
# 4  A3TV7QFYXAG130  B0069R7TAM     5.0  1402963200

# %%
## size
df.shape
# Out:
# (78245, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78245 entries, 0 to 78244
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userid     78245 non-null  object
#  1   productid  78245 non-null  object
#  2   rating     78245 non-null  float64
#  3   date       78245 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
## describe
df.describe()
# Out:
#              rating          date
# count  78245.000000  7.824500e+04
# mean       4.006454  1.338128e+09
# std        1.385342  6.891994e+07
# min        1.000000  9.320832e+08
# 25%        3.000000  1.315008e+09
# 50%        5.000000  1.360800e+09
# 75%        5.000000  1.386029e+09
# max        5.000000  1.406074e+09

# %%
## missing values
df.isnull().sum()
# Out:
# userid       0
# productid    0
# rating       0
# date         0
# dtype: int64

# %%
## duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
##drop timestamp
df.drop(columns=['date'], inplace=True, errors='ignore')

# %%
df.nunique()
# Out:
# userid       76430
# productid    40228
# rating           5
# dtype: int64

# %%
##rating distribution
sns.countplot(x='rating',data=df)
plt.show()

# %% [raw]
# The rating distribution is highly skewed towards higher ratings, with the majority of users giving ratings of 4 and 5. This indicates a positive bias in user feedback. However, such skewness may reduce the model's ability to differentiate between user preferences, which can impact the effectiveness of clustering and recommendation.

# %%
## user activity
user_count=df['userid'].value_counts()
print(user_count.describe())
# Out:
# count    76430.000000
# mean         1.023747
# std          0.177128
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          8.000000
# Name: count, dtype: float64

# %%
# Top 10 active users
print(user_count.head(10))
# Out:
# userid
# A3LGT6UZL99IW1    8
# A1ODOGXEYECQQ8    8
# ADLVFFE4VBT8      7
# ARBKYIVNYWK3C     7
# A27TN8D0CZ8LUY    6
# AVPNQUVZWMDSX     6
# A15QYHQH80W30L    6
# A2AY4YUOX2N1BQ    6
# A2J8T58Z4X15IO    5
# A5JLAU2ARJ0BO     5
# Name: count, dtype: int64

# %%
## rating per user
user_counts = df['userid'].value_counts()
sns.histplot(user_counts,bins=40)
plt.show()

# %% [raw]
# The majority of users have provided only a single rating, indicating low user engagement. This results in sparse user behavior, which can negatively impact clustering and recommendation performance. Therefore, filtering active users is necessary to improve model quality.

# %%
## product popularity
product_count=df['productid'].value_counts()
print(product_count.describe())
# Out:
# count    40228.000000
# mean         1.945038
# std          3.766158
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        201.000000
# Name: count, dtype: float64

# %%
# Top 10 popular products
print(product_count.head(10))
# Out:
# productid
# B0074BW614    201
# B00DR0PDNE    179
# B007WTAJTO    147
# B006GWO5WK    126
# B003ELYQGG    126
# B0019EHU8G    123
# B00622AG6S    113
# B008OHNZI0    112
# B007R5YDYA    108
# B003ES5ZUU    102
# Name: count, dtype: int64

# %%
## rating per product
product_counts=df['productid'].value_counts()
sns.histplot(product_counts,bins=40)
plt.show()

# %% [raw]
# Most products have very few ratings, while a small number of products are highly rated. This indicates a long-tail distribution and potential popularity bias. Low-interaction products may affect recommendation quality, so filtering is required.

# %%
##sparsity check
num_users = df['userid'].nunique()
num_products = df['productid'].nunique()
sparsity = 1 - (len(df) / (num_users * num_products))
print("Sparsity:", sparsity)
# Out:
# Sparsity: 0.999974551376661

# %% [raw]
# Sparsity Analysis
# The dataset exhibited extremely high sparsity (~99.99%), indicating very few user-product interactions.
# This makes traditional recommendation approaches ineffective.
# Conclusion:
# To overcome this, product-level aggregated features were used for clustering.

# %%
## user product matrix
df_sample = df.sample(
    min(5000, len(df)),
    random_state=42
)

user_product_matrix = df_sample.pivot_table(
    index='userid',
    columns='productid',
    values='rating'
)

user_product_matrix.head()
# Out:
# productid              0972683275  140053271X  1615543570  8866139874  \
# userid
# A004818027168B4NOA0VS         NaN         NaN         NaN         NaN
# A0376615V71DIP2WFF6M          NaN         NaN         NaN         NaN
# A0498079L5Z4YA0JYG18          NaN         NaN         NaN         NaN
# A06473612XTXEYXU71T96         NaN         NaN         NaN         NaN
# A06494733GBVPWN385203         NaN         NaN         NaN         NaN
#
# productid              9984971805  B00000J1V5  B00000J4GP  B00000JBAT  \
# userid
# A004818027168B4NOA0VS         NaN         NaN         NaN         NaN
# A0376615V71DIP2WFF6M          NaN         NaN         NaN         NaN
# A0498079L5Z4YA0JYG18          NaN         NaN         NaN         NaN
# A06473612XTXEYXU71T96         NaN         NaN         NaN         NaN
# A06494733GBVPWN385203         NaN         NaN         NaN         NaN
#
# productid              B00000JBHE  B00000K135  ...  B00JIFMXSK  B00JJG7MAW  \
# ...

# %%
## product features
product_features = df.groupby('productid').agg({
    'rating': ['mean', 'count']})
product_features.columns = ['avg_rating', 'rating_count']
product_features.reset_index(inplace=True)
product_features.head()
# Out:
#     productid  avg_rating  rating_count
# 0  0594481813    5.000000             1
# 1  0972683275    4.428571             7
# 2  0983947600    5.000000             1
# 3  1400501466    5.000000             1
# 4  1400501776    5.000000             1

# %% [markdown]
# ### Model Building

# %% [markdown]
# ##### KMeans

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
X=product_features[['avg_rating','rating_count']]

# %%
std_sca=StandardScaler()
X_sca=std_sca.fit_transform(X)

# %%
## elbow methode- to find best cluster
inertia=[]
for i in range(1,10):
    kmeans = KMeans(
    n_clusters=i,
    random_state=42,
    n_init=10
)
    kmeans.fit(X_sca)
    inertia.append(kmeans.inertia_)
plt.plot(range(1,10),inertia,marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %% [raw]
# Elbow Method
# The elbow method was used to determine the optimal number of clusters.
# A sharp decrease in inertia was observed up to k = 3, after which the curve flattened.
# Conclusion:
# The optimal number of clusters was selected as 3.

# %%
# Based on elbow method, optimal K = 3
kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)
product_features['km_cluster']=kmeans.fit_predict(X_sca)

# %%
##visualize
plt.scatter(product_features['rating_count'],product_features['avg_rating'],
            c=product_features['km_cluster'])
plt.xlabel('Rating Count')
plt.ylabel('Average Rating')
plt.title('Product Clusters')
plt.show()

# %%
product_features.groupby('km_cluster')[['avg_rating', 'rating_count']].mean()
# Out:
#             avg_rating  rating_count
# km_cluster
# 0             4.624971      1.829945
# 1             4.240414     32.641115
# 2             2.006777      1.431530

# %%
#Evaluation
score_kmeans=silhouette_score(X_sca,product_features['km_cluster'])
print(f'Silhouette Score:{score_kmeans}')
# Out:
# Silhouette Score:0.6477783856469254

# %% [raw]
# KMeans Clustering Result
# Products were grouped into three clusters based on rating and popularity.
# Cluster 1 represents highly rated and popular products, making it ideal for recommendation.
# Cluster 0 contains niche high-rated products, while Cluster 2 contains low-rated products.

# %% [markdown]
# ##### Hierarchical

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
## visual cluster
sample_size = min(1000, X_sca.shape[0])

sample_data = X_sca[
    np.random.choice(
        X_sca.shape[0],
        sample_size,
        replace=False
    )
]
linked = linkage(sample_data, method='ward')

plt.figure(figsize=(10,5))
dendrogram(linked)
plt.title('Dendrogram (Sample Data)')
plt.show()

# %% [raw]
# Dendrogram Analysis
# A dendrogram was plotted using hierarchical clustering.
# Significant vertical gaps were observed in the plot.
# Based on the largest separation, the optimal number of clusters was determined as 3.

# %%
##hierarchical
hc = AgglomerativeClustering(n_clusters=3)
product_features['hc_cluster'] = hc.fit_predict(X_sca)

# %%
## evaluation
score_hc = silhouette_score(X_sca, product_features['hc_cluster'])
print("Hierarchical Silhouette Score:", score_hc)
# Out:
# Hierarchical Silhouette Score: 0.657231115237227

# %%
## visualization
plt.scatter(
    product_features['rating_count'],
    product_features['avg_rating'],
    c=product_features['hc_cluster']
)

plt.xlabel('Rating Count')
plt.ylabel('Average Rating')
plt.title('Hierarchical Clustering Results')
plt.show()

# %%
## cluster
product_features.groupby('hc_cluster')[['avg_rating', 'rating_count']].mean()
# Out:
#             avg_rating  rating_count
# hc_cluster
# 0             4.233099     20.352708
# 1             1.980359      1.285673
# 2             4.613114      1.699699

# %% [raw]
# Hierarchical clustering grouped the products into three distinct clusters based on their average rating and rating count. The first cluster consists of popular and well-rated products, which have high user engagement and good ratings. The second cluster contains low-rated products with minimal interactions, indicating poor quality. The third cluster represents highly rated but less popular products, often referred to as niche or hidden gems.
#
# The model achieved a silhouette score of 0.65, indicating good separation between clusters. Overall, the clustering effectively captured meaningful patterns in the data and helped identify different categories of products for recommendation purposes.

# %% [markdown]
# ##### DBScan

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan=DBSCAN(eps=0.5,min_samples=5)
product_features['db_cluster'] = dbscan.fit_predict(X_sca)

# %%
##check clusters
product_features['db_cluster'].value_counts()
# Out:
# db_cluster
#  0    40184
# -1       31
#  1       13
# Name: count, dtype: int64

# %%
labels = product_features['db_cluster']

n_clusters = len(set(labels)) - (1 if -1 in labels else 0)

if n_clusters > 1:
    valid_points = labels != -1

    score_db = silhouette_score(
        X_sca[valid_points],
        labels[valid_points]
    )

    print("DBSCAN Silhouette Score:", score_db)
else:
    score_db = -1
    print("Not enough clusters for silhouette score")
# Out:
# DBSCAN Silhouette Score: 0.8888388540980997

# %%
## visualize
import matplotlib.pyplot as plt

plt.scatter(
    product_features['rating_count'],
    product_features['avg_rating'],
    c=product_features['db_cluster']
)

plt.xlabel('Rating Count')
plt.ylabel('Average Rating')
plt.title('DBSCAN Clustering')
plt.show()

# %%
## cluster analysis
product_features.groupby('db_cluster')[['avg_rating', 'rating_count']].mean()
# Out:
#             avg_rating  rating_count
# db_cluster
# -1            4.266230     88.451613
#  0            3.933673      1.863901
#  1            4.247616     46.461538

# %% [raw]
# DBSCAN Result
# DBSCAN produced one dominant cluster containing the majority of data points.
# A few small clusters and noise points were identified.
# Although the silhouette score was high (~0.88), the clustering was highly imbalanced.
# Conclusion:
# DBSCAN failed to provide meaningful segmentation and was not suitable for this dataset.

# %%
# DBSCAN Tuning
 
eps_values = [0.3, 0.5, 1.0]
min_samples_values = [3, 5, 10]

results = []

for eps in eps_values:
    for min_s in min_samples_values:

        db = DBSCAN(
            eps=eps,
            min_samples=min_s
        )

        labels = db.fit_predict(X_sca)

        # Number of clusters excluding noise
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)

        # Number of noise points
        noise = list(labels).count(-1)

        # Silhouette score
        if n_clusters > 1:
            valid_points = labels != -1

            score = silhouette_score(
                X_sca[valid_points],
                labels[valid_points]
            )
        else:
            score = -1

        results.append(
            (eps, min_s, n_clusters, noise, score)
        )

# Create results DataFrame AFTER loops
results_df = pd.DataFrame(
    results,
    columns=[
        'eps',
        'min_samples',
        'clusters',
        'noise_points',
        'silhouette_score'
    ]
)

# Show best DBSCAN combinations
print(
    results_df.sort_values(
        by='silhouette_score',
        ascending=False
    ).head(10)
)
# Out:
#    eps  min_samples  clusters  noise_points  silhouette_score
# 7  1.0            5         2            15          0.934276
# 6  1.0            3         3            11          0.934213
# 3  0.5            3         3            26          0.890098
# 4  0.5            5         2            31          0.888839
# 5  0.5           10         5            37          0.848820
# 0  0.3            3         7            34          0.845947
# 1  0.3            5         6            45          0.733915
# 2  0.3           10         1            95         -1.000000
# 8  1.0           10         1            28         -1.000000

# %% [raw]
# DBSCAN Tuning Result
# Multiple combinations of eps and min_samples were tested.
# Although DBSCAN achieved high silhouette scores (~0.93), the clusters were highly imbalanced with one dominant cluster.
# Conclusion:
# DBSCAN did not produce meaningful segmentation and was not suitable for this dataset.

# %% [markdown]
# #### Comparison

# %%
comparison = pd.DataFrame({
    'Model': ['KMeans', 'Hierarchical', 'DBSCAN'],
    'Silhouette Score': [
        score_kmeans,
        score_hc,
        results_df['silhouette_score'].max()
    ]
})

comparison
# Out:
#           Model  Silhouette Score
# 0        KMeans          0.647778
# 1  Hierarchical          0.657231
# 2        DBSCAN          0.934276

# %%
# Final Model Selection
best_model = "KMeans"
cluster_col = "km_cluster"

print("Final Selected Model:", best_model)
# Out:
# Final Selected Model: KMeans

# %% [raw]
# 📊 Model Comparison Conclusion
#
# In this project, three clustering algorithms—KMeans, Hierarchical Clustering, and DBSCAN—were applied to group products based on average rating and rating count.
#
# KMeans produced three interpretable product clusters and provides good scalability for handling a large number of products. Hierarchical Clustering achieved a slightly higher silhouette score than KMeans, but it is computationally more expensive and less suitable for large-scale applications.
#
# DBSCAN achieved the highest silhouette score; however, its best configuration produced only two clusters along with noise points. Therefore, it was less suitable for creating meaningful product segments for this recommendation system.
#
# Hence, KMeans was selected as the final model because it provides a good balance between scalability, interpretability, and practical usability. The resulting product clusters are used to identify similar products and generate recommendations.

# %%
def recommend_similar_products(product_id, top_n=5):

    if product_id not in product_features['productid'].values:
        return None

    cluster_id = product_features[
        product_features['productid'] == product_id
    ]['km_cluster'].values[0]

    similar_products = product_features[
        product_features['km_cluster'] == cluster_id
    ]

    similar_products = similar_products[
        similar_products['productid'] != product_id
    ]

    similar_products = similar_products.sort_values(
        by=['rating_count', 'avg_rating'],
        ascending=False
    )

    return similar_products[
        ['productid', 'avg_rating', 'rating_count']
    ].head(top_n)

# %% [raw]
# The recommended products belong to the cluster containing highly rated and popular items.
# These products have high average ratings and large interaction counts.
# Conclusion:
# The system successfully identifies and recommends top-performing products

# %%
recommend_similar_products('B0074BW614')
# Out:
#         productid  avg_rating  rating_count
# 37744  B00DR0PDNE    3.932961           179
# 30211  B007WTAJTO    4.557823           147
# 27588  B006GWO5WK    4.523810           126
# 17448  B003ELYQGG    4.333333           126
# 9970   B0019EHU8G    4.723577           123

# %%
# Save file for deployment

product_features.to_csv('product_features.csv', index=False)

# %%
print("product_features.csv saved successfully!")
# Out:
# product_features.csv saved successfully!

# %%
print("Final product features:")
print(product_features.head())

print("\nShape:")
print(product_features.shape)

print("\nColumns:")
print(product_features.columns.tolist())
# Out:
# Final product features:
#     productid  avg_rating  rating_count  km_cluster  hc_cluster  db_cluster
# 0  0594481813    5.000000             1           0           2           0
# 1  0972683275    4.428571             7           0           2           0
# 2  0983947600    5.000000             1           0           2           0
# 3  1400501466    5.000000             1           0           2           0
# 4  1400501776    5.000000             1           0           2           0
#
# Shape:
# (40228, 6)
#
# Columns:
# ['productid', 'avg_rating', 'rating_count', 'km_cluster', 'hc_cluster', 'db_cluster']
